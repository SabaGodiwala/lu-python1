# %%
#write the prime number 
#enter the number 
#output "yes this prime "
#"No this not prime "

# %%
num= int(input("Enter a number: "))
if num<=1:
  print(f"{num} is not a prime number")
else:
  for i in range(2,num):
    if (num%i) ==0:
      print(f"{num} is not a prime number")
      break
  else:
      print(f"{num} is a prime number")
# Out:
# Enter a number: 7
# 7 is a prime number
