# %%
# 1. check the "is" operator on the  float and string & write you findings

# %%
#Srting

# %%
string1 = "hello world"
string2 = "hello"
string3 = "world"
string4 = "hello world"

print(string1==string2)
print(string1==string4)
print(string2==string3)

print(string1 is string4)
print(string1 is not string4)

print(id(string1))
print(id(string4))
# Out:
# False
# True
# False
# False
# True
# 140551418479856
# 140551417579632

# %%
#floats

# %%
f1 = 0.0
f2 = 0.0

print(id(f1))
print(id(f2))


print(f1==f2)

f1 is f2
# Out:
# 140551418168336
# 140551418168752
# True
# False

# %%
print(float(0)==float(0.0))
print(float(0) is float(0.0))
print(id(float(0)))
print(id(float(0.0)))
# Out:
# True
# False
# 140551417287760
# 140551417288272

# %%
#fidings
#it can be concluded that there is a difference in comparison with == and is 
#string1 equals to string4 but string1 is not string4 
#similarly float(0) equals to (0.0) but 0 is not 0.0
#though they have equal values, their id's/adresses are different

# %%
#2. 1>3 > 4  how to solve

# %%
print(1>3>4)

print(1>3 or 3>4)
print(1>3 and 3>4)
# Out:
# False
# False
# False
